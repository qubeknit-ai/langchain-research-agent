# %%
import os
from dotenv import load_dotenv

# Load variables from the .env file into the environment
load_dotenv()

# Read configuration with sensible defaults
MODEL_NAME = os.getenv("MODEL_NAME", "qwen3")
TEMPERATURE = float(os.getenv("TEMPERATURE", "0.7"))

print(f"Model       : {MODEL_NAME}")
print(f"Temperature : {TEMPERATURE}")
# Out:
# Model       : minimax-m2.5:cloud
# Temperature : 0.7

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model=MODEL_NAME,
    temperature=TEMPERATURE,
)

print(f"LLM initialized: {llm.model}")
# Out:
# LLM initialized: minimax-m2.5:cloud

# %%
def get_weather(city: str) -> str:
    return f"It's always sunny in {city}!"


print(get_weather("Lahore"))
# Out:
# It's always sunny in Lahore!

# %%
def get_time(city: str) -> str:
    """Get the current date and time."""
    from datetime import datetime
    return datetime.now()

# %%
from langchain.agents import create_agent

# Create the agent using the LangChain 1.x API
agent = create_agent(
    model=llm,
    tools=[get_weather, get_time],
    system_prompt="You are a helpful assistant. Use the available tools when needed.",
)

print("Agent created successfully.")
print(f"Type: {type(agent).__name__}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from langchain.agents import create_agent
#       3 # Create the agent using the LangChain 1.x API
# ----> 4 agent = create_agent(
#       5     model=llm,
#       6     tools=[get_weather, get_time],
#       7     system_prompt="You are a helpful assistant. Use the available tools when needed.",
#       8 )
#      10 print("Agent created successfully.")
#      11 print(f"Type: {type(agent).__name__}")
#
# File d:\NAVTTC\langchain-agent\.venv\Lib\site-packages\langchain\agents\factory.py:891, in create_agent(model, tools, system_prompt, middleware, response_format, state_schema, context_schema, checkpointer, store, interrupt_before, interrupt_after, debug, name, cache)
#     886 available_tools = middleware_tools + regular_tools
#     888 # Create ToolNode if we have client-side tools OR if middleware defines wrap_tool_call
#     889 # (which may handle dynamically registered tools)
#     890 tool_node = (
# --> 891     ToolNode(
#     892         tools=available_tools,
#     893         wrap_tool_call=wrap_tool_call_wrapper,
#     894         awrap_tool_call=awrap_tool_call_wrapper,
#     895     )
#     896     if available_tools or wrap_tool_call_wrapper or awrap_tool_call_wrapper
#     897     else None
#     898 )
#     900 # Default tools for ModelRequest initialization
#     901 # Use converted BaseTool instances from ToolNode (not raw callables)
#     902 # Include built-ins and converted tools (can be changed dynamically by middleware)
#     903 # Structured tools are NOT included - they're added dynamically based on response_format
#     904 if tool_node:
#
# File d:\NAVTTC\langchain-agent\.venv\Lib\site-packages\langgraph\prebuilt\tool_node.py:775, in ToolNode.__init__(self, tools, name, tags, handle_tool_errors, messages_key, wrap_tool_call, awrap_tool_call)
#     773 for tool in tools:
#     774     if not isinstance(tool, BaseTool):
# --> 775         tool_ = create_tool(cast("type[BaseTool]", tool))
#     776     else:
#     777         tool_ = tool
#
# File d:\NAVTTC\langchain-agent\.venv\Lib\site-packages\langchain_core\tools\convert.py:361, in tool(name_or_callable, runnable, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, extras, *args)
#     355 if name_or_callable is not None:
#     356     if callable(name_or_callable) and hasattr(name_or_callable, "__name__"):
#     357         # Used as a decorator without parameters
#     358         # @tool
#     359         # def my_tool():
#     360         #    pass
# --> 361         return _create_tool_factory(name_or_callable.__name__)(name_or_callable)
#     362     if isinstance(name_or_callable, str):
#     363         # Used with a new name for the tool
#     364         # @tool("search")
#    (...)    371         # def my_tool():
#     372         #    pass
#     373         return _create_tool_factory(name_or_callable)
#
# File d:\NAVTTC\langchain-agent\.venv\Lib\site-packages\langchain_core\tools\convert.py:304, in tool.<locals>._create_tool_factory.<locals>._tool_factory(dec_func)
#     301     schema = args_schema
#     303 if infer_schema or args_schema is not None:
# --> 304     return StructuredTool.from_function(
#     305         func,
#     306         coroutine,
#     307         name=tool_name,
#     308         description=tool_description,
#     309         return_direct=return_direct,
#     310         args_schema=schema,
#     311         infer_schema=infer_schema,
#     312         response_format=response_format,
#     313         parse_docstring=parse_docstring,
#     314         error_on_invalid_docstring=error_on_invalid_docstring,
#     315         extras=extras,
#     316     )
#     317 # If someone doesn't want a schema applied, we must treat it as
#     318 # a simple string->string function
#     319 if dec_func.__doc__ is None:
#
# File d:\NAVTTC\langchain-agent\.venv\Lib\site-packages\langchain_core\tools\structured.py:235, in StructuredTool.from_function(cls, func, coroutine, name, description, return_direct, args_schema, infer_schema, response_format, parse_docstring, error_on_invalid_docstring, **kwargs)
#     233 if description_ is None:
#     234     msg = "Function must have a docstring if description not provided."
# --> 235     raise ValueError(msg)
#     236 if description is None:
#     237     # Only apply if using the function's docstring
#     238     description_ = textwrap.dedent(description_).strip()
#
# ValueError: Function must have a docstring if description not provided.

# %% [markdown]
# When Remove DocString it will give `ValueError:`, DocString is the description of that tool from which an LLM know what this tool does and what tool to call
